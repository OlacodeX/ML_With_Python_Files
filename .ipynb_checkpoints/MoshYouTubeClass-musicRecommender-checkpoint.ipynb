# %%
# The Problem,
# We want to develop a model that takes previous user data and suggests the genre of music the user will like 
# based on their age and gender.

# %%
import pandas as pd
# load data
music_data = pd.read_csv('../ML/files/music.csv')
# Check basic stat of data
music_data.describe()
# Out:
#                age       gender
# count  2304.000000  2304.000000
# mean     27.944444     0.500000
# std       4.984078     0.500109
# min      20.000000     0.000000
# 25%      25.000000     0.000000
# 50%      28.000000     0.500000
# 75%      31.000000     1.000000
# max      37.000000     1.000000

# %%
# Define X and y where y is the desired output i.e the predictions we want to make from the available data.
# X is/are the parameters we want to use to get our predictions
X = music_data.drop(columns=['genre']) #This creates a new dataframe without the genre column
y = music_data['genre']

# %%
# To make sure our model is well trained and accurate, we need to split our data set into test & train sets
# To do this we need to import the function from sklearn model_selection
from sklearn.model_selection import train_test_split
# The function returns a turple so we can just unpack it directly
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
y_test
# Out:
# 1346     Acoustic
# 351         Dance
# 2263     Acoustic
# 1566       HipHop
# 1932    Classical
#           ...
# 299         Dance
# 255          Jazz
# 1355         Jazz
# 2144       HipHop
# 1810        Dance
# Name: genre, Length: 692, dtype: object

# %%
# import model to use - here we use decision tree from scikitlearn
from sklearn.tree import DecisionTreeClassifier

# set model to a variable
model = DecisionTreeClassifier()
# fit model i.e perform analysis. We will pass the two training sets to train the model.
model.fit(X_train, y_train)

# make predictions i.e test model
predictions = model.predict(X_test)
predictions
# Out:
# array(['Acoustic', 'Dance', 'Acoustic', 'HipHop', 'Classical', 'HipHop',
#        'Classical', 'Dance', 'Acoustic', 'HipHop', 'Classical', 'Jazz',
#        'Classical', 'Acoustic', 'Dance', 'Dance', 'Classical',
#        'Classical', 'Classical', 'Classical', 'Classical', 'Acoustic',
#        'Acoustic', 'Acoustic', 'Classical', 'Classical', 'Dance',
#        'Acoustic', 'Classical', 'Dance', 'Acoustic', 'HipHop', 'Dance',
#        'Jazz', 'Acoustic', 'Jazz', 'Dance', 'Classical', 'Classical',
#        'Acoustic', 'HipHop', 'Jazz', 'Dance', 'Jazz', 'Acoustic',
#        'Acoustic', 'Jazz', 'Jazz', 'HipHop', 'HipHop', 'Classical',
#        'HipHop', 'Jazz', 'Acoustic', 'HipHop', 'Acoustic', 'HipHop',
#        'Dance', 'Acoustic', 'Jazz', 'Classical', 'Acoustic', 'Classical',
#        'HipHop', 'Classical', 'Jazz', 'Classical', 'Acoustic', 'HipHop',
#        'Jazz', 'Classical', 'Classical', 'Acoustic', 'Acoustic', 'Jazz',
#        'Jazz', 'Jazz', 'Classical', 'Dance', 'Dance', 'Dance', 'Acoustic',
#        'HipHop', 'Classical', 'Dance', 'Classical', 'Acoustic',
#        'Classical', 'Acoustic', 'HipHop', 'Dance', 'Classical', 'HipHop',
#        'Dance', 'Classical', 'Dance', 'Dance', 'Jazz', 'Classical',
#        'Dance', 'HipHop', 'HipHop', 'HipHop', 'Classical', 'Classical',
#        'Dance', 'Classical', 'Dance', 'Jazz', 'Classical', 'Classical',
#        'Dance', 'Jazz', 'Classical', 'Acoustic', 'Dance', 'Dance',
#        'HipHop', 'HipHop', 'Dance', 'HipHop', 'Acoustic', 'Classical',
#        'Dance', 'Acoustic', 'Jazz', 'Dance', 'HipHop', 'Dance', 'Jazz',
#        'Classical', 'Classical', 'Classical', 'HipHop', 'Acoustic',
#        'Classical', 'Acoustic', 'HipHop', 'Jazz', 'Classical', 'Dance',
#        'Classical', 'HipHop', 'Classical', 'Jazz', 'Acoustic', 'HipHop',
#        'Classical', 'Jazz', 'Classical', 'Acoustic', 'Classical',
#        'HipHop', 'Classical', 'Dance', 'Acoustic', 'Acoustic',
#        'Classical', 'Acoustic', 'Dance', 'Acoustic', 'Acoustic', 'HipHop',
#        'HipHop', 'Jazz', 'Dance', 'Classical', 'Classical', 'Classical',
#        'Jazz', 'Jazz', 'Dance', 'Jazz', 'Dance', 'HipHop', 'Classical',
#        'Classical', 'HipHop', 'Jazz', 'Acoustic', 'Classical', 'Jazz',
#        'Dance', 'Dance', 'Classical', 'Acoustic', 'Dance', 'Dance',
#        'Jazz', 'Classical', 'Classical', 'Acoustic', 'Acoustic', 'Dance',
#        'Jazz', 'Dance', 'Dance', 'Acoustic', 'Acoustic', 'Classical',
#        'HipHop', 'Classical', 'Dance', 'Acoustic', 'Classical', 'Jazz',
#        'HipHop', 'Acoustic', 'Classical', 'Classical', 'HipHop', 'HipHop',
#        'Dance', 'Classical', 'HipHop', 'Acoustic', 'Jazz', 'Classical',
#        'Acoustic', 'Acoustic', 'HipHop', 'HipHop', 'Acoustic',
#        'Classical', 'Dance', 'HipHop', 'HipHop', 'Acoustic', 'Acoustic',
#        'Jazz', 'Classical', 'Classical', 'Jazz', 'Jazz', 'HipHop',
#        'Acoustic', 'HipHop', 'HipHop', 'Classical', 'Dance', 'Acoustic',
#        'Acoustic', 'Classical', 'Classical', 'Jazz', 'Acoustic',
#        'Classical', 'HipHop', 'Acoustic', 'Acoustic', 'Classical', 'Jazz',
#        'Dance', 'Acoustic', 'Dance', 'HipHop', 'Acoustic', 'Classical',
#        'HipHop', 'Dance', 'Classical', 'Dance', 'Dance', 'Acoustic',
#        'HipHop', 'Classical', 'Acoustic', 'Acoustic', 'Classical',
#        'Dance', 'Dance', 'Dance', 'HipHop', 'Acoustic', 'Jazz',
#        'Acoustic', 'Classical', 'Classical', 'Jazz', 'Dance', 'Dance',
#        'Classical', 'Classical', 'Acoustic', 'Dance', 'Classical',
#        'Classical', 'HipHop', 'Dance', 'Classical', 'Dance', 'HipHop',
#        'Jazz', 'Classical', 'HipHop', 'Dance', 'Jazz', 'Classical',
#        'Dance', 'Dance', 'Classical', 'Classical', 'Classical',
#        'Classical', 'Classical', 'Acoustic', 'Classical', 'Classical',
#        'Jazz', 'Jazz', 'Acoustic', 'Jazz', 'Classical', 'Jazz',
#        'Acoustic', 'HipHop', 'HipHop', 'Dance', 'Dance', 'Classical',
#        'HipHop', 'Classical', 'Acoustic', 'Jazz', 'Classical', 'Acoustic',
#        'Acoustic', 'Classical', 'HipHop', 'Classical', 'Classical',
#        'Dance', 'Jazz', 'Acoustic', 'Acoustic', 'Classical', 'Dance',
#        'Classical', 'Classical', 'Jazz', 'Jazz', 'HipHop', 'Classical',
#        'Dance', 'Jazz', 'Classical', 'Acoustic', 'Classical', 'Classical',
#        'Classical', 'Dance', 'Acoustic', 'Jazz', 'Jazz', 'HipHop',
#        'Classical', 'Classical', 'Classical', 'HipHop', 'Acoustic',
#        'Dance', 'Classical', 'Acoustic', 'Classical', 'Jazz', 'Dance',
#        'Dance', 'Dance', 'Jazz', 'Classical', 'HipHop', 'Dance',
#        'Acoustic', 'Acoustic', 'Jazz', 'Classical', 'HipHop', 'Dance',
#        'Classical', 'Classical', 'Jazz', 'HipHop', 'Classical', 'Jazz',
#        'HipHop', 'Acoustic', 'Classical', 'HipHop', 'Acoustic',
#        'Acoustic', 'Classical', 'Classical', 'Dance', 'Classical',
#        'Classical', 'Dance', 'Classical', 'Acoustic', 'HipHop', 'Jazz',
#        'Classical', 'Classical', 'Dance', 'Classical', 'Classical',
#        'Classical', 'Jazz', 'Acoustic', 'Dance', 'Jazz', 'Jazz', 'Jazz',
#        'Classical', 'Dance', 'Jazz', 'Acoustic', 'HipHop', 'Acoustic',
#        'Dance', 'Jazz', 'Jazz', 'Classical', 'Acoustic', 'Classical',
#        'Classical', 'HipHop', 'Acoustic', 'Dance', 'Classical', 'Jazz',
#        'Dance', 'Dance', 'Dance', 'Classical', 'Acoustic', 'HipHop',
#        'Acoustic', 'Classical', 'Dance', 'Classical', 'Acoustic',
#        'Acoustic', 'Classical', 'Dance', 'HipHop', 'HipHop', 'Classical',
#        'HipHop', 'Acoustic', 'Jazz', 'Acoustic', 'HipHop', 'Acoustic',
#        'Classical', 'Jazz', 'Classical', 'Classical', 'Classical',
#        'HipHop', 'Classical', 'Jazz', 'Jazz', 'Acoustic', 'Jazz', 'Dance',
#        'Acoustic', 'Classical', 'Jazz', 'Classical', 'Dance', 'Dance',
#        'Classical', 'HipHop', 'HipHop', 'Acoustic', 'Dance', 'Acoustic',
#        'Acoustic', 'Classical', 'Classical', 'Classical', 'Dance',
#        'Dance', 'Classical', 'HipHop', 'Acoustic', 'Classical',
#        'Classical', 'Dance', 'Acoustic', 'Classical', 'Classical',
#        'HipHop', 'Dance', 'Acoustic', 'Dance', 'Classical', 'Classical',
#        'Classical', 'HipHop', 'Classical', 'Acoustic', 'Classical',
#        'HipHop', 'Jazz', 'Classical', 'Acoustic', 'Acoustic', 'Classical',
#        'Acoustic', 'Acoustic', 'Acoustic', 'Jazz', 'Jazz', 'Acoustic',
#        'HipHop', 'Classical', 'Jazz', 'Acoustic', 'Dance', 'Classical',
#        'Classical', 'Classical', 'Dance', 'HipHop', 'HipHop', 'HipHop',
#        'Classical', 'Acoustic', 'Dance', 'HipHop', 'Jazz', 'Dance',
#        'HipHop', 'Acoustic', 'HipHop', 'Acoustic', 'Classical',
#        'Acoustic', 'Jazz', 'Classical', 'Classical', 'Dance', 'Classical',
#        'Dance', 'HipHop', 'Classical', 'Jazz', 'Classical', 'Classical',
#        'Jazz', 'Dance', 'Acoustic', 'Classical', 'Acoustic', 'Classical',
#        'Jazz', 'Dance', 'HipHop', 'HipHop', 'Jazz', 'Dance', 'Classical',
#        'Acoustic', 'Acoustic', 'Jazz', 'Dance', 'Acoustic', 'Acoustic',
#        'Jazz', 'HipHop', 'HipHop', 'Dance', 'HipHop', 'HipHop', 'Jazz',
#        'Jazz', 'Dance', 'Jazz', 'Jazz', 'Dance', 'Dance', 'Jazz',
#        'Classical', 'Jazz', 'Acoustic', 'Classical', 'HipHop', 'HipHop',
#        'Jazz', 'Acoustic', 'Acoustic', 'HipHop', 'HipHop', 'Dance',
#        'Acoustic', 'HipHop', 'Classical', 'Classical', 'Acoustic',
#        'HipHop', 'Jazz', 'Classical', 'HipHop', 'Jazz', 'Dance', 'Jazz',
#        'Classical', 'Classical', 'Classical', 'Acoustic', 'Dance',
#        'Classical', 'Acoustic', 'HipHop', 'Classical', 'Jazz', 'Dance',
#        'Classical', 'Jazz', 'Classical', 'Classical', 'Acoustic',
#        'Classical', 'Classical', 'Classical', 'Jazz', 'Classical',
#        'Classical', 'HipHop', 'HipHop', 'Jazz', 'Dance', 'Dance', 'Dance',
#        'HipHop', 'Classical', 'HipHop', 'Jazz', 'Classical', 'HipHop',
#        'Dance', 'Dance', 'Classical', 'Classical', 'Classical',
#        'Classical', 'Dance', 'Acoustic', 'Classical', 'HipHop',
#        'Acoustic', 'Classical', 'HipHop', 'HipHop', 'Dance', 'Jazz',
#        'Classical', 'Classical', 'Dance', 'HipHop', 'Classical',
#        'Classical', 'HipHop', 'Jazz', 'Classical', 'Jazz', 'Jazz',
#        'Dance', 'Dance', 'Jazz', 'Classical', 'Classical', 'Classical',
#        'Acoustic', 'Jazz', 'Classical', 'HipHop', 'Classical', 'Jazz',
#        'Classical', 'Jazz', 'Jazz', 'Acoustic', 'HipHop', 'Classical',
#        'Classical', 'Dance', 'Jazz', 'Jazz', 'HipHop', 'Dance'],
#       dtype=object)

# %%
# Evaluate model to know the accuracy
# Import the function to access the accuracy from sklearn
from sklearn.metrics import accuracy_score
#This is done by passing the y_test and the predictions to confirm how accurate our model is
score = accuracy_score(y_test, predictions)
score
# Out:
# 1.0

# %%
# Now I can decide to save already trained model so I don't have to retrain the model all the time 
# This will definitely save computational time.
# We use the function below for this.
import joblib
# This function has two helpers - dump(this saves the model in a file) and load(this loads the model from the file)
# joblib.dump(model, '../ML/files/musicRecommender.joblib') - We comment this out cos the model has now been saved
# Now load the already trained model from joblib and use
model = joblib.load('../ML/files/musicRecommender.joblib')
# Just make predictions now i.e test model
predictions = model.predict(X_test)
predictions
# Out:
# array(['Acoustic', 'Dance', 'Acoustic', 'HipHop', 'Classical', 'HipHop',
#        'Classical', 'Dance', 'Acoustic', 'HipHop', 'Classical', 'Jazz',
#        'Classical', 'Acoustic', 'Dance', 'Dance', 'Classical',
#        'Classical', 'Classical', 'Classical', 'Classical', 'Acoustic',
#        'Acoustic', 'Acoustic', 'Classical', 'Classical', 'Dance',
#        'Acoustic', 'Classical', 'Dance', 'Acoustic', 'HipHop', 'Dance',
#        'Jazz', 'Acoustic', 'Jazz', 'Dance', 'Classical', 'Classical',
#        'Acoustic', 'HipHop', 'Jazz', 'Dance', 'Jazz', 'Acoustic',
#        'Acoustic', 'Jazz', 'Jazz', 'HipHop', 'HipHop', 'Classical',
#        'HipHop', 'Jazz', 'Acoustic', 'HipHop', 'Acoustic', 'HipHop',
#        'Dance', 'Acoustic', 'Jazz', 'Classical', 'Acoustic', 'Classical',
#        'HipHop', 'Classical', 'Jazz', 'Classical', 'Acoustic', 'HipHop',
#        'Jazz', 'Classical', 'Classical', 'Acoustic', 'Acoustic', 'Jazz',
#        'Jazz', 'Jazz', 'Classical', 'Dance', 'Dance', 'Dance', 'Acoustic',
#        'HipHop', 'Classical', 'Dance', 'Classical', 'Acoustic',
#        'Classical', 'Acoustic', 'HipHop', 'Dance', 'Classical', 'HipHop',
#        'Dance', 'Classical', 'Dance', 'Dance', 'Jazz', 'Classical',
#        'Dance', 'HipHop', 'HipHop', 'HipHop', 'Classical', 'Classical',
#        'Dance', 'Classical', 'Dance', 'Jazz', 'Classical', 'Classical',
#        'Dance', 'Jazz', 'Classical', 'Acoustic', 'Dance', 'Dance',
#        'HipHop', 'HipHop', 'Dance', 'HipHop', 'Acoustic', 'Classical',
#        'Dance', 'Acoustic', 'Jazz', 'Dance', 'HipHop', 'Dance', 'Jazz',
#        'Classical', 'Classical', 'Classical', 'HipHop', 'Acoustic',
#        'Classical', 'Acoustic', 'HipHop', 'Jazz', 'Classical', 'Dance',
#        'Classical', 'HipHop', 'Classical', 'Jazz', 'Acoustic', 'HipHop',
#        'Classical', 'Jazz', 'Classical', 'Acoustic', 'Classical',
#        'HipHop', 'Classical', 'Dance', 'Acoustic', 'Acoustic',
#        'Classical', 'Acoustic', 'Dance', 'Acoustic', 'Acoustic', 'HipHop',
#        'HipHop', 'Jazz', 'Dance', 'Classical', 'Classical', 'Classical',
#        'Jazz', 'Jazz', 'Dance', 'Jazz', 'Dance', 'HipHop', 'Classical',
#        'Classical', 'HipHop', 'Jazz', 'Acoustic', 'Classical', 'Jazz',
#        'Dance', 'Dance', 'Classical', 'Acoustic', 'Dance', 'Dance',
#        'Jazz', 'Classical', 'Classical', 'Acoustic', 'Acoustic', 'Dance',
#        'Jazz', 'Dance', 'Dance', 'Acoustic', 'Acoustic', 'Classical',
#        'HipHop', 'Classical', 'Dance', 'Acoustic', 'Classical', 'Jazz',
#        'HipHop', 'Acoustic', 'Classical', 'Classical', 'HipHop', 'HipHop',
#        'Dance', 'Classical', 'HipHop', 'Acoustic', 'Jazz', 'Classical',
#        'Acoustic', 'Acoustic', 'HipHop', 'HipHop', 'Acoustic',
#        'Classical', 'Dance', 'HipHop', 'HipHop', 'Acoustic', 'Acoustic',
#        'Jazz', 'Classical', 'Classical', 'Jazz', 'Jazz', 'HipHop',
#        'Acoustic', 'HipHop', 'HipHop', 'Classical', 'Dance', 'Acoustic',
#        'Acoustic', 'Classical', 'Classical', 'Jazz', 'Acoustic',
#        'Classical', 'HipHop', 'Acoustic', 'Acoustic', 'Classical', 'Jazz',
#        'Dance', 'Acoustic', 'Dance', 'HipHop', 'Acoustic', 'Classical',
#        'HipHop', 'Dance', 'Classical', 'Dance', 'Dance', 'Acoustic',
#        'HipHop', 'Classical', 'Acoustic', 'Acoustic', 'Classical',
#        'Dance', 'Dance', 'Dance', 'HipHop', 'Acoustic', 'Jazz',
#        'Acoustic', 'Classical', 'Classical', 'Jazz', 'Dance', 'Dance',
#        'Classical', 'Classical', 'Acoustic', 'Dance', 'Classical',
#        'Classical', 'HipHop', 'Dance', 'Classical', 'Dance', 'HipHop',
#        'Jazz', 'Classical', 'HipHop', 'Dance', 'Jazz', 'Classical',
#        'Dance', 'Dance', 'Classical', 'Classical', 'Classical',
#        'Classical', 'Classical', 'Acoustic', 'Classical', 'Classical',
#        'Jazz', 'Jazz', 'Acoustic', 'Jazz', 'Classical', 'Jazz',
#        'Acoustic', 'HipHop', 'HipHop', 'Dance', 'Dance', 'Classical',
#        'HipHop', 'Classical', 'Acoustic', 'Jazz', 'Classical', 'Acoustic',
#        'Acoustic', 'Classical', 'HipHop', 'Classical', 'Classical',
#        'Dance', 'Jazz', 'Acoustic', 'Acoustic', 'Classical', 'Dance',
#        'Classical', 'Classical', 'Jazz', 'Jazz', 'HipHop', 'Classical',
#        'Dance', 'Jazz', 'Classical', 'Acoustic', 'Classical', 'Classical',
#        'Classical', 'Dance', 'Acoustic', 'Jazz', 'Jazz', 'HipHop',
#        'Classical', 'Classical', 'Classical', 'HipHop', 'Acoustic',
#        'Dance', 'Classical', 'Acoustic', 'Classical', 'Jazz', 'Dance',
#        'Dance', 'Dance', 'Jazz', 'Classical', 'HipHop', 'Dance',
#        'Acoustic', 'Acoustic', 'Jazz', 'Classical', 'HipHop', 'Dance',
#        'Classical', 'Classical', 'Jazz', 'HipHop', 'Classical', 'Jazz',
#        'HipHop', 'Acoustic', 'Classical', 'HipHop', 'Acoustic',
#        'Acoustic', 'Classical', 'Classical', 'Dance', 'Classical',
#        'Classical', 'Dance', 'Classical', 'Acoustic', 'HipHop', 'Jazz',
#        'Classical', 'Classical', 'Dance', 'Classical', 'Classical',
#        'Classical', 'Jazz', 'Acoustic', 'Dance', 'Jazz', 'Jazz', 'Jazz',
#        'Classical', 'Dance', 'Jazz', 'Acoustic', 'HipHop', 'Acoustic',
#        'Dance', 'Jazz', 'Jazz', 'Classical', 'Acoustic', 'Classical',
#        'Classical', 'HipHop', 'Acoustic', 'Dance', 'Classical', 'Jazz',
#        'Dance', 'Dance', 'Dance', 'Classical', 'Acoustic', 'HipHop',
#        'Acoustic', 'Classical', 'Dance', 'Classical', 'Acoustic',
#        'Acoustic', 'Classical', 'Dance', 'HipHop', 'HipHop', 'Classical',
#        'HipHop', 'Acoustic', 'Jazz', 'Acoustic', 'HipHop', 'Acoustic',
#        'Classical', 'Jazz', 'Classical', 'Classical', 'Classical',
#        'HipHop', 'Classical', 'Jazz', 'Jazz', 'Acoustic', 'Jazz', 'Dance',
#        'Acoustic', 'Classical', 'Jazz', 'Classical', 'Dance', 'Dance',
#        'Classical', 'HipHop', 'HipHop', 'Acoustic', 'Dance', 'Acoustic',
#        'Acoustic', 'Classical', 'Classical', 'Classical', 'Dance',
#        'Dance', 'Classical', 'HipHop', 'Acoustic', 'Classical',
#        'Classical', 'Dance', 'Acoustic', 'Classical', 'Classical',
#        'HipHop', 'Dance', 'Acoustic', 'Dance', 'Classical', 'Classical',
#        'Classical', 'HipHop', 'Classical', 'Acoustic', 'Classical',
#        'HipHop', 'Jazz', 'Classical', 'Acoustic', 'Acoustic', 'Classical',
#        'Acoustic', 'Acoustic', 'Acoustic', 'Jazz', 'Jazz', 'Acoustic',
#        'HipHop', 'Classical', 'Jazz', 'Acoustic', 'Dance', 'Classical',
#        'Classical', 'Classical', 'Dance', 'HipHop', 'HipHop', 'HipHop',
#        'Classical', 'Acoustic', 'Dance', 'HipHop', 'Jazz', 'Dance',
#        'HipHop', 'Acoustic', 'HipHop', 'Acoustic', 'Classical',
#        'Acoustic', 'Jazz', 'Classical', 'Classical', 'Dance', 'Classical',
#        'Dance', 'HipHop', 'Classical', 'Jazz', 'Classical', 'Classical',
#        'Jazz', 'Dance', 'Acoustic', 'Classical', 'Acoustic', 'Classical',
#        'Jazz', 'Dance', 'HipHop', 'HipHop', 'Jazz', 'Dance', 'Classical',
#        'Acoustic', 'Acoustic', 'Jazz', 'Dance', 'Acoustic', 'Acoustic',
#        'Jazz', 'HipHop', 'HipHop', 'Dance', 'HipHop', 'HipHop', 'Jazz',
#        'Jazz', 'Dance', 'Jazz', 'Jazz', 'Dance', 'Dance', 'Jazz',
#        'Classical', 'Jazz', 'Acoustic', 'Classical', 'HipHop', 'HipHop',
#        'Jazz', 'Acoustic', 'Acoustic', 'HipHop', 'HipHop', 'Dance',
#        'Acoustic', 'HipHop', 'Classical', 'Classical', 'Acoustic',
#        'HipHop', 'Jazz', 'Classical', 'HipHop', 'Jazz', 'Dance', 'Jazz',
#        'Classical', 'Classical', 'Classical', 'Acoustic', 'Dance',
#        'Classical', 'Acoustic', 'HipHop', 'Classical', 'Jazz', 'Dance',
#        'Classical', 'Jazz', 'Classical', 'Classical', 'Acoustic',
#        'Classical', 'Classical', 'Classical', 'Jazz', 'Classical',
#        'Classical', 'HipHop', 'HipHop', 'Jazz', 'Dance', 'Dance', 'Dance',
#        'HipHop', 'Classical', 'HipHop', 'Jazz', 'Classical', 'HipHop',
#        'Dance', 'Dance', 'Classical', 'Classical', 'Classical',
#        'Classical', 'Dance', 'Acoustic', 'Classical', 'HipHop',
#        'Acoustic', 'Classical', 'HipHop', 'HipHop', 'Dance', 'Jazz',
#        'Classical', 'Classical', 'Dance', 'HipHop', 'Classical',
#        'Classical', 'HipHop', 'Jazz', 'Classical', 'Jazz', 'Jazz',
#        'Dance', 'Dance', 'Jazz', 'Classical', 'Classical', 'Classical',
#        'Acoustic', 'Jazz', 'Classical', 'HipHop', 'Classical', 'Jazz',
#        'Classical', 'Jazz', 'Jazz', 'Acoustic', 'HipHop', 'Classical',
#        'Classical', 'Dance', 'Jazz', 'Jazz', 'HipHop', 'Dance'],
#       dtype=object)

# %%
# Test again
score = accuracy_score(y_test, predictions)
score
# Out:
# 1.0

# %%
# We can get a graphical representation of the behind the scenes of how the model solves the problem
from sklearn import tree
tree.export_graphviz(model, out_file='../ML/files/musicRecommender.dot', 
                     feature_names=['age', 'gender'], 
                     filled=True, label='all', rounded=True,
                     class_names=sorted(y.unique()))
# Now I will open it in vscode using a pluggin to display
